# %%
import sys
sys.path.append(r"C:\Users\TAN PHAT\OneDrive\Desktop\banking-customer-churn\Code")

# %%
# import thu vien
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import classification_report, make_scorer, recall_score
from imblearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from xgboost import XGBClassifier
import lazypredict
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
import re
from cleaning.clean import clean_missing, clean_dtype, clean_outliers, clean_data_1
import os

# %%
churn_data = clean_data_1('../Dataset_before_cleaning/banking_customer_churn.csv')
churn_data = clean_outliers(churn_data)
# Out:
# Kich thuoc du lieu truoc khi lam sach:  (10007, 17)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 churn_data = clean_data_1('../Dataset_before_cleaning/banking_customer_churn.csv')
# ----> 2 churn_data = clean_outliers(churn_data)
#
# File ~\OneDrive\Desktop\banking-customer-churn\Code\cleaning\clean.py:104, in clean_outliers(data)
#     102 # xoa oulier bang phuong phap IQR
#     103 for col in cols:
# --> 104     Q1 = data[col].quantile(0.25)
#     105     Q2 = data[col].quantile(0.75)
#     106     IQR = Q2 -Q1
#
# File c:\Users\TAN PHAT\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:2898, in Series.quantile(self, q, interpolation)
#    2894 # We dispatch to DataFrame so that core.internals only has to worry
#    2895 #  about 2D cases.
#    2896 df = self.to_frame()
# ...
