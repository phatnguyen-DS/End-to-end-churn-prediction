# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## KIỂM TRA DỮ LIỆU

# %%
churn_data = pd.read_csv("../Dataset_cleaned/banking_customer_churn_cleaned.csv")
#lay 10 mau ngau nhien kiem tra do sach du lieu
churn_data.sample(n= 10)
# Out:
#       Unnamed: 0  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 2068        2146        850.0    France    Male   49       5  122486.50
# 3504        3635        740.0    France  Female   37       5       0.00
# 6100        6333        634.0    France    Male   34       8  105302.70
# 7647        7944        520.0    France  Female   39       1   73493.17
# 4071        4230        670.0    France  Female   41      10       0.00
# 8534        8864        832.0    France  Female   29       5       0.00
# 8573        8905        557.0    France    Male   36       3       0.00
# 3707        3849        646.0     Spain    Male   32       1       0.00
# 6464        6711        666.0   Germany  Female   36       3  129118.50
# 8470        8799        454.0    France    Male   34       4       0.00
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 2068              1          0               1         59748.19       0
# 3504              2          1               1         27528.40       0
# 6100              1          1               1        123165.00       0
# 7647              1          0               1        109626.10       1
# 4071              3          1               0         81602.02       0
# 8534              2          1               0        178779.50       0
# 8573              1          0               1        144078.00       0
# 3707              2          1               0        183289.20       0
# 6464              2          0               0        139435.10       0
# 8470              2          1               0        198817.70       0
#
#       Satisfaction Score Card Type  Point Earned
# 2068                   3   DIAMOND           852
# 3504                   5  PLATINUM           798
# 6100                   1   DIAMOND           378
# 7647                   2    SILVER           721
# 4071                   4   DIAMOND           378
# 8534                   5  PLATINUM           922
# 8573                   4    SILVER           880
# 3707                   3   DIAMOND           307
# 6464                   1   DIAMOND           940
# 8470                   2  PLATINUM           731

# %%
# ve boxplot
sns.set_theme(style="whitegrid")

fig, ax = plt.subplots(2, 2, figsize=(20, 7))

cols = ['CreditScore', 'Balance', 'EstimatedSalary', 'Point Earned']
titles = ['Credit Score', 'Balance', 'Estimated Salary', 'Point Earned']

for i, (col, title) in enumerate(zip(cols, titles)):
    row, col_idx = divmod(i, 2)
    sns.boxplot(
        x=churn_data[col],
        ax=ax[row, col_idx],
        color=sns.color_palette("Set2")[i],
        width=0.6,
        fliersize=4
    )
    ax[row, col_idx].set_title(title, fontsize=14, fontweight='bold')
    ax[row, col_idx].set_xlabel('')
    ax[row, col_idx].set_ylabel('')
    ax[row, col_idx].ticklabel_format(style='plain', axis='x')  # ⚙️ Bỏ ký hiệu e
    ax[row, col_idx].grid(True, linestyle="--", alpha=0.6)

plt.suptitle('Distribution of Key Numerical Features', fontsize=16, fontweight='bold', color='#333')
plt.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ## EDA – EXPLORATORY DATA ANALYSIS

# %%
#kiem tra cac gia tri trong cac cot
pd.set_option('display.float_format', '{:.0f}'.format)
for col in churn_data.columns:
    print(f'{churn_data[col].value_counts()} \n')
# Out:
# Unnamed: 0
# 9999    1
# 0       1
# 1       1
# 2       1
# 3       1
#        ..
# 15      1
# 14      1
# 13      1
# 12      1
# 11      1
# Name: count, Length: 9625, dtype: int64
#
# CreditScore
# 850    223
# 678     61
# 705     51
# 655     51
# 684     51
#       ...
# 424      1
# 412      1
# 441      1
# 442      1
# 440      1
# Name: count, Length: 450, dtype: int64
#
# Geography
# France     4826
# Germany    2421
# Spain      2378
# Name: count, dtype: int64
#
# Gender
# Male      5257
# Female    4368
# Name: count, dtype: int64
#
# Age
# 37    482
# 35    474
# 38    473
# 36    455
# 34    447
# 33    442
# 40    431
# 39    422
# 32    418
# 31    404
# 41    366
# 29    347
# 30    326
# 42    319
# 43    297
# 28    272
# 44    255
# 45    229
# 46    225
# 27    209
# 26    200
# 47    175
# 48    168
# 25    154
# 49    147
# 50    134
# 24    132
# 51    118
# 52    101
# 23     99
# 22     84
# 54     83
# 55     82
# 53     74
# 57     74
# 56     70
# 58     67
# 59     62
# 60     61
# 61     53
# 21     53
# 62     52
# 20     40
# 19     27
# 18     22
# Name: count, dtype: int64
#
# Tenure
# 2     1004
# 7      999
# 8      996
# 1      991
# 5      979
# 3      971
# 4      956
# 9      939
# 6      927
# 10     470
# 0      393
# Name: count, dtype: int64
#
# Balance
# 0         3478
# 141750       2
# 113882       2
# 130171       2
# 131835       2
#           ...
# 88381        1
# 155060       1
# 57370        1
# 75075        1
# 83808        1
# Name: count, Length: 6135, dtype: int64
#
# NumOfProducts
# 1    4882
# 2    4434
# 3     251
# 4      58
# Name: count, dtype: int64
#
# HasCrCard
# 1    6785
# 0    2840
# Name: count, dtype: int64
#
# IsActiveMember
# 1    4847
# 0    4778
# Name: count, dtype: int64
#
# EstimatedSalary
# 188574    2
# 173366    2
# 177235    2
# 184525    2
# 196258    2
#          ..
# 2988      1
# 99596     1
# 53445     1
# 115146    1
# 190858    1
# Name: count, Length: 9613, dtype: int64
#
# Exited
# 0    7676
# 1    1949
# Name: count, dtype: int64
#
# Satisfaction Score
# 3    1963
# 4    1946
# 2    1944
# 5    1925
# 1    1847
# Name: count, dtype: int64
#
# Card Type
# SILVER      2418
# DIAMOND     2417
# PLATINUM    2398
# GOLD        2392
# Name: count, dtype: int64
#
# Point Earned
# 709    25
# 408    24
# 629    23
# 244    23
# 240    22
#        ..
# 714     3
# 996     2
# 163     1
# 119     1
# 206     1
# Name: count, Length: 785, dtype: int64
